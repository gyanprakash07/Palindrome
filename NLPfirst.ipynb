# %% [markdown]
# <a href="https://colab.research.google.com/github/gyanprakash07/Palindrome/blob/main/NLPfirst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
import os
import nltk.corpus
print(os.listdir(nltk.data.find('corpora')))
# Out:
# ['propbank.zip', 'problem_reports.zip', 'mte_teip5.zip', 'sinica_treebank', 'omw.zip', 'twitter_samples.zip', 'genesis.zip', 'nonbreaking_prefixes.zip', 'semcor.zip', 'timit', 'movie_reviews', 'verbnet3.zip', 'sentiwordnet', 'masc_tagged.zip', 'biocreative_ppi.zip', 'dependency_treebank.zip', 'extended_omw.zip', 'mac_morpho', 'ptb.zip', 'lin_thesaurus.zip', 'senseval', 'nps_chat.zip', 'alpino.zip', 'cess_cat.zip', 'treebank', 'shakespeare', 'nps_chat', 'pil.zip', 'europarl_raw.zip', 'jeita.zip', 'words', 'cess_esp.zip', 'pros_cons.zip', 'indian', 'subjectivity.zip', 'names', 'treebank.zip', 'europarl_raw', 'ycoe', 'ppattach.zip', 'framenet_v15.zip', 'chat80.zip', 'product_reviews_1.zip', 'city_database', 'swadesh.zip', 'senseval.zip', 'qc', 'webtext.zip', 'crubadan', 'alpino', 'dolch.zip', 'wordnet31.zip', 'problem_reports', 'mac_morpho.zip', 'brown', 'sentence_polarity', 'ieer.zip', 'biocreative_ppi', 'city_database.zip', 'nombank.1.0.zip', 'kimmo', 'ieer', 'switchboard', 'comtrans.
# ...

# %%
from nltk.corpus import brown
print(nltk.corpus.brown.fileids())
print(len(brown.words()))
# Out:
# ['ca01', 'ca02', 'ca03', 'ca04', 'ca05', 'ca06', 'ca07', 'ca08', 'ca09', 'ca10', 'ca11', 'ca12', 'ca13', 'ca14', 'ca15', 'ca16', 'ca17', 'ca18', 'ca19', 'ca20', 'ca21', 'ca22', 'ca23', 'ca24', 'ca25', 'ca26', 'ca27', 'ca28', 'ca29', 'ca30', 'ca31', 'ca32', 'ca33', 'ca34', 'ca35', 'ca36', 'ca37', 'ca38', 'ca39', 'ca40', 'ca41', 'ca42', 'ca43', 'ca44', 'cb01', 'cb02', 'cb03', 'cb04', 'cb05', 'cb06', 'cb07', 'cb08', 'cb09', 'cb10', 'cb11', 'cb12', 'cb13', 'cb14', 'cb15', 'cb16', 'cb17', 'cb18', 'cb19', 'cb20', 'cb21', 'cb22', 'cb23', 'cb24', 'cb25', 'cb26', 'cb27', 'cc01', 'cc02', 'cc03', 'cc04', 'cc05', 'cc06', 'cc07', 'cc08', 'cc09', 'cc10', 'cc11', 'cc12', 'cc13', 'cc14', 'cc15', 'cc16', 'cc17', 'cd01', 'cd02', 'cd03', 'cd04', 'cd05', 'cd06', 'cd07', 'cd08', 'cd09', 'cd10', 'cd11', 'cd12', 'cd13', 'cd14', 'cd15', 'cd16', 'cd17', 'ce01', 'ce02', 'ce03', 'ce04', 'ce05', 'ce06', 'ce07', 'ce08', 'ce09', 'ce10', 'ce11', 'ce12', 'ce13', 'ce14', 'ce15', 'ce16', 'ce17', 'ce18', 'ce19', 'ce20
# ...

# %%
for i in brown.words():
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# Some
# persons
# consider
# the
# work
# on
# a
# farm
# recreational
# .
# For
# some
# white-collar
# workers
# it
# is
# a
# welcome
# change
# from
# the
# regular
# job
# ,
# and
# a
# physical
# conditioner
# .
# Land
# ,
# labor
# ,
# and
# equipment
# needed
# Part-time
# farming
# can
# take
# comparatively
# little
# land
# ,
# labor
# ,
# and
# equipment
# --
# or
# a
# great
# deal
# .
# It
# depends
# on
# the
# kind
# and
# the
# scale
# of
# the
# farming
# operation
# .
# General
# requirements
# for
# land
# ,
# labor
# ,
# and
# equipment
# are
# discussed
# below
# .
# Specific
# requirements
# for
# each
# of
# various
# types
# of
# enterprises
# are
# discussed
# on
# pages
# 8
# to
# 14
# .
# Land
# Three
# quarters
# to
# 1
# acre
# of
# good
# land
# is
# enough
# for
# raising
# fruits
# and
# vegetables
# for
# home
# use
# ,
# and
# for
# a
# small
# flock
# of
# chickens
# ,
# a
# cow
# ,
# and
# two
# ...

# %%
for i in range(501):
  print(brown.words()[i])
# Out:
# The
# Fulton
# County
# Grand
# Jury
# said
# Friday
# an
# investigation
# of
# Atlanta's
# recent
# primary
# election
# produced
# ``
# no
# evidence
# ''
# that
# any
# irregularities
# took
# place
# .
# The
# jury
# further
# said
# in
# term-end
# presentments
# that
# the
# City
# Executive
# Committee
# ,
# which
# had
# over-all
# charge
# of
# the
# election
# ,
# ``
# deserves
# the
# praise
# and
# thanks
# of
# the
# City
# of
# Atlanta
# ''
# for
# the
# manner
# in
# which
# the
# election
# was
# conducted
# .
# The
# September-October
# term
# jury
# had
# been
# charged
# by
# Fulton
# Superior
# Court
# Judge
# Durwood
# Pye
# to
# investigate
# reports
# of
# possible
# ``
# irregularities
# ''
# in
# the
# hard-fought
# primary
# which
# was
# won
# by
# Mayor-nominate
# Ivan
# Allen
# Jr.
# .
# ``
# Only
# a
# relative
# handful
# of
# such
# reports
# was
# received
# ''
# ,
# the
# jury
# said
# ,
# ``
# considering
# the
# widespread
# interest
# in
# the
# ...

# %%
#tokenizattion
ML= "In credit card processing, information can be tokenized when a card is swiped at the merchant’s point of sale (POS) system or when payment details are entered into a virtual terminal. Once a system has the cardholder data, it is passed to the credit card networks for authorization. After being authorized, a token is randomly generated that is passed back to the merchant, and store"
print(type(ML))
from nltk.tokenize import word_tokenize
ML_tokens = word_tokenize(ML)
print(ML_tokens)
print(len(ML_tokens))
# Out:
# <class 'str'>
# ['In', 'credit', 'card', 'processing', ',', 'information', 'can', 'be', 'tokenized', 'when', 'a', 'card', 'is', 'swiped', 'at', 'the', 'merchant', '’', 's', 'point', 'of', 'sale', '(', 'POS', ')', 'system', 'or', 'when', 'payment', 'details', 'are', 'entered', 'into', 'a', 'virtual', 'terminal', '.', 'Once', 'a', 'system', 'has', 'the', 'cardholder', 'data', ',', 'it', 'is', 'passed', 'to', 'the', 'credit', 'card', 'networks', 'for', 'authorization', '.', 'After', 'being', 'authorized', ',', 'a', 'token', 'is', 'randomly', 'generated', 'that', 'is', 'passed', 'back', 'to', 'the', 'merchant', ',', 'and', 'store']
# 75

# %%
#word_count
#freq functiongives frequnecy
from nltk.probability import FreqDist
fdist = FreqDist()
for word in ML_tokens:
  #to convert all tokens in lowercase
  fdist[word.lower()]+=1
fdist
# Out:
# FreqDist({',': 4, 'a': 4, 'is': 4, 'the': 4, 'card': 3, 'credit': 2, 'when': 2, 'merchant': 2, 'system': 2, '.': 2, ...})
